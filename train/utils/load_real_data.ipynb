# %%
import cfusdlog
logdata = cfusdlog.decode('/media/naliseas-workstation/crazyflie/log26')['fixedFrequency']
logdata
# Out:
# {'timestamp': array([68228.036, 68231.992, 68235.955, ..., 83468.345, 83472.234,
#         83476.188]),
#  'stabilizer.roll': array([-0.15824039, -0.15824039, -0.15964967, ..., -1.46441758,
#         -1.45870936, -1.44976497]),
#  'stabilizer.pitch': array([ 0.68005222,  0.68005222,  0.67878217, ..., -0.55917752,
#         -0.55679733, -0.55401254]),
#  'stabilizer.yaw': array([0.29481286, 0.29481286, 0.294819  , ..., 9.53021908, 9.48775387,
#         9.44369507]),
#  'stateEstimateZ.x': array([-2198, -2198, -2198, ..., -2249, -2249, -2249]),
#  'stateEstimateZ.y': array([-1691, -1691, -1691, ..., -1701, -1701, -1701]),
#  'stateEstimateZ.z': array([33, 33, 33, ..., 33, 33, 33]),
#  'stateEstimate.vx': array([ 0.00615103,  0.00615103,  0.00655198, ..., -0.0119789 ,
#         -0.01194291, -0.01106197]),
#  'stateEstimate.vy': array([-0.00178086, -0.00178086, -0.00195746, ...,  0.02617355,
#          0.02579629,  0.02731299]),
# ...

# %%
index = logdata['motor.m1req'] > 0

# %%
logdata['motor.m1req'][index].shape
# Out:
# (3844,)
